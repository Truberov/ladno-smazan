# %%
# !pip install docling
# Out:
# Requirement already satisfied: docling in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (2.4.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2024.8.30)
# Requirement already satisfied: deepsearch-glm<0.27.0,>=0.26.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (0.26.1)
# Requirement already satisfied: docling-core<3.0.0,>=2.3.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.3.1)
# Requirement already satisfied: docling-ibm-models<3.0.0,>=2.0.3 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.0.3)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.0.3)
# Requirement already satisfied: easyocr<2.0,>=1.7 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (0.26.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.1.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.2.2)
# Requirement already satisfied: pyarrow<17.0.0,>=16.1.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (16.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.9.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.6.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (4.30.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (1.14.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling) (0.12.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.5)
# Requirement already satisfied: docutils!=0.21 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (0.21.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (1.26.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (1.0.1)
# Requirement already satisfied: pywin32<308,>=307 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (307)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (13.7.1)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (4.66.4)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-core<3.0.0,>=2.3.0->docling) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-core<3.0.0,>=2.3.0->docling) (4.22.0)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-core<3.0.0,>=2.3.0->docling) (10.3.0)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (3.1.0)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (4.9.4)
# Requirement already satisfied: mean_average_precision<2022.0.0.0,>=2021.4.26.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (2021.4.26.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (4.10.0.84)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (2.4.1+cu121)
# Requirement already satisfied: torchvision<1,>=0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from docling-ibm-models<3.0.0,>=2.0.3->docling) (0.19.1+cu121)
# Requirement already satisfied: scikit-image in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (0.24.0)
# Requirement already satisfied: python-bidi in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (0.6.3)
# Requirement already satisfied: PyYAML in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (2.0.6)
# Requirement already satisfied: pyclipper in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from easyocr<2.0,>=1.7->docling) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub<1,>=0.23->docling) (4.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.23.4)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from python-pptx<2.0.0,>=1.0.2->docling) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.3->docling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.3->docling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.3->docling) (2.2.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from typer<0.13.0,>=0.12.5->docling) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from typer<0.13.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: colorama in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from click>=8.0.0->typer<0.13.0,>=0.12.5->docling) (0.4.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<3.0.0,>=2.0.3->docling) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.3.0->docling) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.3.0->docling) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.3.0->docling) (0.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (2.18.0)
# Requirement already satisfied: sympy in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.3->docling) (1.12)
# Requirement already satisfied: networkx in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.3->docling) (3.3)
# Requirement already satisfied: jinja2 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.3->docling) (3.1.4)
# Requirement already satisfied: imageio>=2.33 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.3->docling) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\wurfil\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.3->docling) (1.3.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from docling.backend.pypdfium2_backend import PyPdfiumDocumentBackend
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.models.tesseract_ocr_cli_model import TesseractCliOcrOptions
from docling.models.tesseract_ocr_model import TesseractOcrOptions
from docling_core.types.doc import ImageRefMode, PictureItem, TableItem, TextItem

pipeline_options = PdfPipelineOptions()

pipeline_options.generate_table_images = True
pipeline_options.generate_picture_images = True
pipeline_options.do_table_structure = True
pipeline_options.do_ocr = False
pipeline_options.table_structure_options.do_cell_matching = False


doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# %%
import os

def definition_data(element, current_page_data):
    if isinstance(element, TableItem):
        current_page_data['tables'].append(element)
    if isinstance(element, TextItem):
        current_page_data['texts'].append(element)
    return current_page_data

def transform_data(current_page_data):
    row = {
        'document': '',
        'page_num': '',
        'table_markdown': '',
        'text': '',
    }
    for table in current_page_data['tables']:
        row['table_markdown'] = table.export_to_markdown()
    pharagraph = []

    for text in current_page_data['texts']:
        if text.label != 'page_footer':
            pharagraph.append(text.text)

    pharagraph.append(row['table_markdown'])
    row['text'] = '\n'.join(pharagraph)

    return row

def get_data(conv_res):
    rows = []
    current_page_number = 1
    current_page_data = {
        'tables': [],
        'texts': [],
    }
    
    for element, _level in conv_res.document.iterate_items():
        new_page_number = element.prov[0].page_no
        if new_page_number != current_page_number:
            row = transform_data(current_page_data)
            row['document'] = conv_res.input.file.name  # Исправлено с result на conv_res
            row['page_num'] = current_page_number

            rows.append(row)
            current_page_number = new_page_number
            current_page_data = {
                'tables': [],
                'texts': [],
            }
        current_page_data = definition_data(element, current_page_data)
    
    # Добавляем обработку последней страницы
    row = transform_data(current_page_data)
    row['document'] = conv_res.input.file.name
    row['page_num'] = current_page_number
    rows.append(row)
    
    return rows

rows = []

import os
from multiprocessing import Pool, Manager
from functools import partial
from tqdm import tqdm

def proccessDoc(shared_rows, input_doc_path, file_name):
    try:
        conv_result = doc_converter.convert(input_doc_path)
        new_rows = get_data(conv_result)
        with shared_rows.get_lock():
            shared_rows.extend(new_rows)
        return True, f"Успешно обработан файл: {file_name}"
    except Exception as e:
        return False, f"Ошибка при обработке файла {file_name}: {str(e)}"

def proccessDocs(dir, num_processes=None):
    if num_processes is None:
        num_processes = os.cpu_count() - 1
    
    # Получаем список всех файлов
    files = [(os.path.join(dir, file), file.split('.')[0]) 
             for file in os.listdir(dir)]
    total_files = len(files)
    
    # Создаем общий список и счетчик для прогресса
    with Manager() as manager:
        shared_rows = manager.list()
        
        # Создаем частичную функцию с общим списком
        process_func = partial(proccessDoc, shared_rows)
        
        # Инициализируем счетчики для статистики
        success_count = 0
        error_count = 0
        
        print(f"\nНачало обработки {total_files} файлов используя {num_processes} процессов")
        
        # Запускаем пул процессов с прогресс-баром
        with Pool(processes=num_processes) as pool:
            with tqdm(total=total_files, desc="Обработка файлов", 
                     unit="файл", ncols=100) as pbar:
                
                # Используем imap для возможности обновления прогресс-бара
                for success, message in pool.imap_unordered(process_func, files):
                    if success:
                        success_count += 1
                    else:
                        error_count += 1
                        print(f"\n{message}")
                    pbar.update()
        
        # Преобразуем shared_rows обратно в обычный список
        global rows
        rows = list(shared_rows)
        
        # Выводим итоговую статистику
        print("\nИтоги обработки:")
        print(f"✓ Успешно обработано: {success_count} файлов")
        if error_count > 0:
            print(f"✗ Ошибок обработки: {error_count} файлов")
        print(f"Всего извлечено строк: {len(rows)}")

# %%
def convert_doc(input_doc_path: str) -> list:
    conv_result = doc_converter.convert(input_doc_path)
    new_rows = get_data(conv_result)

    return new_rows

# %%
import os
_dir = 'input'

files = [(os.path.join(_dir, file)) for file in os.listdir(_dir)]

# %%
from tqdm import tqdm

def process_documents(files):
    converted_docs = []
    successful = 0
    failed = 0
    
    for file in tqdm(files, desc="Обработка файлов"):
        try:
            result = convert_doc(file)
            if result:
                converted_docs.extend(result)
                successful += 1
            else:
                failed += 1
        except Exception as e:
            failed += 1
            print(f"Ошибка при обработке {file}: {str(e)}")
    
    print(f"\nОбработка завершена:")
    print(f"Успешно: {successful}")
    print(f"С ошибками: {failed}")
    print(f"Всего извлечено строк: {len(converted_docs)}")
    
    return converted_docs
converted_docs = process_documents(files)
# Out:
# Обработка файлов:  24%|███████████████                                               | 17/70 [17:51<1:05:20, 73.97s/it]
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# Обработка файлов:  34%|████████████████████▏                                      | 24/70 [1:37:24<3:22:26, 264.06s/it]
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# Обработка файлов:  47%|█████████████████████████████▏                                | 33/70 [1:42:30<22:49, 37.02s/it]Encountered an error during conversion of document 62fd8b2fb60a5693c23aab39c30f0cb769e155912b0ffa90e4d0563d949e7361:
# Traceback (most recent call last):
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 149, in _build_document
#     for p in pipeline_pages:  # Must exhaust!
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 116, in _apply_on_pages
#     yield from page_batch
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\page_assemble_model.py", line 59, in __call__
#     for page in page_batch:
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\table_structure_model.py", line 166, in __call__
#     text_piece = page._backend.get_text_in_rect(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 62, in get_text_in_rect
#     overlap_frac = cell_bbox.intersection_area_with(bbox) / cell_bbox.area()
#                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#
# ZeroDivisionError: float division by zero
#
# Обработка файлов:  49%|██████████████████████████████                                | 34/70 [1:42:42<17:49, 29.70s/it]
# Ошибка при обработке input\39.pdf: float division by zero
# Обработка файлов:  50%|███████████████████████████████                               | 35/70 [1:43:25<19:33, 33.54s/it]
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# Обработка файлов:  54%|█████████████████████████████████▋                            | 38/70 [1:50:19<42:46, 80.20s/it]
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# Обработка файлов:  56%|██████████████████████████████████▌                           | 39/70 [1:51:05<36:10, 70.01s/it]Encountered an error during conversion of document e291b305b4cbf12dbe79b51429c1abf848e641f515dffbb32b8769eff2b7860c:
# Traceback (most recent call last):
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 149, in _build_document
#     for p in pipeline_pages:  # Must exhaust!
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 116, in _apply_on_pages
#     yield from page_batch
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\page_assemble_model.py", line 59, in __call__
#     for page in page_batch:
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\table_structure_model.py", line 166, in __call__
#     text_piece = page._backend.get_text_in_rect(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 62, in get_text_in_rect
#     overlap_frac = cell_bbox.intersection_area_with(bbox) / cell_bbox.area()
#                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#
# ZeroDivisionError: float division by zero
#
# Обработка файлов:  57%|███████████████████████████████████▍                          | 40/70 [1:51:56<32:14, 64.47s/it]
# Ошибка при обработке input\44.pdf: float division by zero
# Обработка файлов:  80%|████████████████████████████████████████████████▊            | 56/70 [3:33:09<58:49, 252.07s/it]
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# *ERR* --- *ERR*
# *ERR* Table is not square! *ERR*
# *Padding to square...*
# Обработка файлов:  87%|█████████████████████████████████████████████████████▏       | 61/70 [3:44:02<15:02, 100.33s/it]Encountered an error during conversion of document 61d2f566e0e6a25594b13f8727761b5b458e74300bd94f0599550519df7a3a08:
# Traceback (most recent call last):
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 149, in _build_document
#     for p in pipeline_pages:  # Must exhaust!
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 116, in _apply_on_pages
#     yield from page_batch
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\page_assemble_model.py", line 59, in __call__
#     for page in page_batch:
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\table_structure_model.py", line 166, in __call__
#     text_piece = page._backend.get_text_in_rect(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 62, in get_text_in_rect
#     overlap_frac = cell_bbox.intersection_area_with(bbox) / cell_bbox.area()
#                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#
# ZeroDivisionError: float division by zero
#
# Обработка файлов:  89%|██████████████████████████████████████████████████████▉       | 62/70 [3:44:09<09:38, 72.34s/it]
# Ошибка при обработке input\64.pdf: float division by zero
# Encountered an error during conversion of document d78ada7eb0aa81c08a3e691c3b4078df94a65312e4cebb4f428d38f54c250d02:
# Traceback (most recent call last):
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 149, in _build_document
#     for p in pipeline_pages:  # Must exhaust!
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\pipeline\base_pipeline.py", line 116, in _apply_on_pages
#     yield from page_batch
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\page_assemble_model.py", line 59, in __call__
#     for page in page_batch:
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\models\table_structure_model.py", line 166, in __call__
#     text_piece = page._backend.get_text_in_rect(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 62, in get_text_in_rect
#     overlap_frac = cell_bbox.intersection_area_with(bbox) / cell_bbox.area()
#                    ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
#
# ZeroDivisionError: float division by zero
#
# Обработка файлов:  90%|███████████████████████████████████████████████████████▊      | 63/70 [3:45:07<07:55, 67.92s/it]
# Ошибка при обработке input\65.pdf: float division by zero
# Обработка файлов: 100%|█████████████████████████████████████████████████████████████| 70/70 [3:59:01<00:00, 204.87s/it]
# Обработка завершена:
# Успешно: 66
# С ошибками: 4
# Всего извлечено строк: 4452

# %%
res = process_documents(files)
# Out:
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 0.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\0.pdf: Input document input\0.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 1.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\1.pdf: Input document input\1.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 14.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\14.pdf: Input document input\14.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 13.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\13.pdf: Input document input\13.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 12.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\12.pdf: Input document input\12.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 17.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\17.pdf: Input document input\17.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 18.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\18.pdf: Input document input\18.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 19.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\19.pdf: Input document input\19.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 16.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\16.pdf: Input document input\16.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 20.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\20.pdf: Input document input\20.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 15.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\15.pdf: Input document input\15.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 22.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\22.pdf: Input document input\22.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 21.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\21.pdf: Input document input\21.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 11.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\11.pdf: Input document input\11.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 2.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\2.pdf: Input document input\2.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 24.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\24.pdf: Input document input\24.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 26.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\26.pdf: Input document input\26.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 27.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\27.pdf: Input document input\27.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 10.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\10.pdf: Input document input\10.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 23.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\23.pdf: Input document input\23.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 30.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\30.pdf: Input document input\30.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 3.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\3.pdf: Input document input\3.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 31.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\31.pdf: Input document input\31.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 25.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\25.pdf: Input document input\25.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 33.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\33.pdf: Input document input\33.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 34.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\34.pdf: Input document input\34.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 28.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\28.pdf: Input document input\28.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 35.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 36.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\35.pdf: Input document input\35.pdf is not valid.
# ERROR:root:Ошибка при обработке .\input\36.pdf: Input document input\36.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 38.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\38.pdf: Input document input\38.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 37.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\66.pdf: Input document input\66.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 65.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\65.pdf: Input document input\65.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 68.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\68.pdf: Input document input\68.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 46.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\46.pdf: Input document input\46.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 7.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\7.pdf: Input document input\7.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 69.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\69.pdf: Input document input\69.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 44.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\44.pdf: Input document input\44.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 9.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\9.pdf: Input document input\9.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 67.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\67.pdf: Input document input\67.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 8.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\8.pdf: Input document input\8.pdf is not valid.
# ERROR:docling.datamodel.document:An unexpected error occurred while opening the document 64.pdf
# Traceback (most recent call last):
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 120, in __init__
#     self._init_doc(backend, path_or_stream)
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\datamodel\document.py", line 173, in _init_doc
#     self._backend = backend(self, path_or_stream=path_or_stream)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\docling\backend\docling_parse_backend.py", line 194, in __init__
#     self._pdoc = pdfium.PdfDocument(self.path_or_stream)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 78, in __init__
#     self.raw, to_hold, to_close = _open_pdf(self._input, self._password, self._autoclose)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\wurfil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pypdfium2\_helpers\document.py", line 678, in _open_pdf
#     raise PdfiumError(f"Failed to load document (PDFium: {pdfium_i.ErrorToStr.get(err_code)}).")
# pypdfium2._helpers.misc.PdfiumError: Failed to load document (PDFium: Data format error).
# ERROR:root:Ошибка при обработке .\input\64.pdf: Input document input\64.pdf is not valid.

# %%
# import pandas as pd
import pandas as pd

df = pd.DataFrame(rows)
df.to_csv('stucture_data.csv')
